# %%
# %matplotlib inline

# %%
data =  {
    'love': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10], 
    'sad':  [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10],
    'emotionless': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10],
    'disgust': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10],
    'anger': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10],
    'surprise': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10],
    'fear': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10],
    'happiness': [10, 60, 20, 33, 44, 55, 66, 77, 25, 50, 10, 30, 40, 10, 10]
 }

# %%
import matplotlib.pyplot as plt

def plotMovie(data, color_map = 'plasma'):

    cmap =  plt.cm.get_cmap(color_map)

    f, ax = plt.subplots(figsize=(20,10))

    # positions of the left bar-boundaries
    keys_size = float(len(data.keys()))
    data_size = len(data[data.keys()[0]])
    bar_l = [i+1 for i in range(data_size)] 

    # positions of the x-axis ticks (center of the bars as bar labels)
    tick_pos = [i+(1/2) for i in bar_l] 

    cum = None
    for (index, (label, series)) in enumerate(data.items()):

        # plot bar
        ax.bar(
            bar_l, series,
            bottom=cum, label=label,
            alpha=0.8, color = cmap(index / keys_size),
            width=1.0
        )    

        cum = series if not cum else [x + y for x, y in zip(cum, series)]

    ax.set_ylabel("Count")
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xlim([min(tick_pos), max(tick_pos)])
    plt.grid()

    plt.show()

# %%
plotMovie(data)

# %%
plotMovie2(data, data)
